# %% [markdown]
# A TUPLe is a collection which is  ordred and unchangeable and allow duplicate values

# %%
mytuple=('manish','gupta','amity','university')
print(type(mytuple))
print(mytuple)
# Out:
# <class 'tuple'>
# ('manish', 'gupta', 'amity', 'university')

# %% [markdown]
# tp create tuple with one item you have to add a comma at last ,otherwise python will not recognise it as tuple

# %%
mytuple=('manish',)
print(mytuple)
# Out:
# ('manish',)

# %% [markdown]
# elements of tuple cannot be channged so we convert it into list

# %%
mytuple=('manish','gupta','amity','university')
mytuple1=list(mytuple)
mytuple1[1]='aditya'
print(type(mytuple1))
mytuple=tuple(mytuple1)
print(mytuple)
print(type(mytuple))
# Out:
# <class 'list'>
# ('manish', 'aditya', 'amity', 'university')
# <class 'tuple'>

# %%
mytuple=('manish','gupta','amity','university')
print(mytuple[3])
print(mytuple[-3])
# Out:
# university
# gupta
