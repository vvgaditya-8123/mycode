# %%
dic={'manish':'teacher','adiitya':'student'}
print(dic)
print(dic['manish'])
dic['manish']
# Out:
# {'manish': 'teacher', 'adiitya': 'student'}
# teacher
# 'teacher'

# %%
dic={'manish':'teacher','adiitya':'student'}
dic.keys()
# Out:
# dict_keys(['manish', 'adiitya'])

# %%
dic={'manish':'teacher','adiitya':'student'}
dic.items()
# Out:
# dict_items([('manish', 'teacher'), ('adiitya', 'student')])

# %%
dic={'manish':'teacher','adiitya':'student'}
dic.values()
# Out:
# dict_values(['teacher', 'student'])

# %%
dic={'manish':'teacher','adiitya':'student'}
del dic['manish']
print(dic)
dic.pop('adiitya')
print(dic)
# Out:
# {'adiitya': 'student'}
# {}
